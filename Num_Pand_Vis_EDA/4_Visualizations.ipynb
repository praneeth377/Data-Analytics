# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data = sns.load_dataset('tips')
data.head()
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
x = np.linspace(0,10,100)
y = np.exp(x)
plt.xlabel('X-Axis')
plt.ylabel('Y-axis')
plt.title('Exponential Graph')

plt.plot(x,y,'g*')
plt.show()

# %%
x = np.linspace(-100,100,1000)          # Standard Logit Curve 
L = 1
k = 1
x_0 = 0
y = L/(1+(np.exp(-k*(x-x_0))))
plt.ylim(0,1)
plt.xlim(-5,5)
plt.plot(x,y,'g')
plt.show()

# %%
x = np.linspace(-10,10,100)
y1 = x
y2 = x**2
y3 = np.sqrt(x)
y4 = x**3

plt.ylim(-5,5)
plt.axhline(color = 'black', linewidth=0.5)
plt.axvline(color = 'black', linewidth=0.5)

plt.plot(x,y1,'r',x,y2,'g',x,y3,'b',x,y4,'orange')
plt.show()
# Out:
# C:\Users\prane\AppData\Local\Temp\ipykernel_16580\1289952022.py:4: RuntimeWarning: invalid value encountered in sqrt
#   y3 = np.sqrt(x)

# %%
x = data['total_bill']
y = data['tip']

plt.scatter(x,y,s=np.array(y)**2,c='green')   # custom sizing so that large tips will be large dots 

plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.title('Scatter Plot')
plt.show()

# %%
# Bar Plot basic example
amount = [10000,21000,5000,8000,12500]
names = ['Arvind','Kesava','Chaitanya','Rahul','Mahesh']
#x_pos = np.arange(len(names))
x_pos = [1,2,3,4,5]
plt.bar(x_pos, amount, width= 0.6)
plt.xticks(x_pos, names)

plt.title('Distribution of Bill Amount')
plt.xlabel('Names')
plt.ylabel('Amount')
plt.figure(figsize=(20,10))

plt.show()

# %%
d21 = pd.DataFrame({'Year':[2001,2002,2003,2004,2005], 'Import':[54.4,53.8,61.6,74.15,89.33], 'Export':[42.5,44.5,48.3,57.24,69.18]})


plt.bar(d21['Year'], height=d21['Import'], width=0.35, label='Import')
plt.bar(d21['Year']+0.35, height=d21['Export'], width=0.35, label='Export')

plt.xticks(ticks=d21['Year']+(0.35/2), labels=d21['Year'])
plt.title('Import and Export by Year')
plt.legend()
plt.show()

# %%
data['smoker'].value_counts().values         # This is new and very useful. See below cell to get it
# Out:
# array([151,  93], dtype=int64)

# %%
a = data['smoker'].value_counts()
plt.bar(a.index,a.values,width=0.3,color='r')
plt.text(x=-0.05,y=data['smoker'].value_counts().values[0]+1,s=data['smoker'].value_counts().values[0])
plt.text(x=0.98,y=data['smoker'].value_counts().values[1]+1,s=data['smoker'].value_counts().values[1])
plt.xlabel('Smoker types')
plt.ylabel('Frequency')
plt.show()

# %%
data['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
plt.pie(data['day'].value_counts(), labels=['Sat','Sun','Thus','Fri'],autopct='%.1f%%',explode=[0,0,0,0.1])
plt.show()

# %%
d23 = pd.DataFrame({'Income Form':['Corporation Tax','Income Tax','Customs','Union Excise Duties','GST & Other Taxes','Non-Tax Revenue',
'Non-Debt Capital Receipts','Borrowings and Other Liabilities'], 'Amount(in paise)':[21,16,4,8,19,9,3,20]})

plt.pie(d23['Amount(in paise)'], labels=d23['Income Form'], autopct='%.1f%%', startangle=90)

circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(circle)

plt.show()

# %%
plt.hist(data['tip'],bins=5,color='r',width=1.6,histtype='barstacked')
c,b = np.histogram(data['tip'], bins=5,)
print(c,b)
plt.xlabel('Bin Distribution')
plt.ylabel('Frequency')
plt.title('Tip Histogram')
plt.show()
# Out:
# [120  93  24   5   2] [ 1.   2.8  4.6  6.4  8.2 10. ]

# %%
plt.boxplot(data['total_bill'])
plt.text(x=1.1,y=data['total_bill'].min(),s= data['total_bill'].min())
plt.text(x=1.1,y=data['total_bill'].max(),s= data['total_bill'].max())
plt.text(x=1.1,y=data['total_bill'].median(),s= f"Median: {data['total_bill'].median():.2f}")
plt.text(x=1.1,y=data['total_bill'].quantile(0.75),s= f"Q3: {data['total_bill'].quantile(0.75):.2f}")    # Good example of using f string and rounding off
plt.text(x=1.1,y=data['total_bill'].quantile(0.25),s= data['total_bill'].quantile(0.25))


plt.show()

# %%
data.count()
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
colors = ['orange','red']
sns.stripplot( y = 'tip', x = 'time', data= data, palette=colors)
plt.show()
# Out:
# C:\Users\prane\AppData\Local\Temp\ipykernel_16580\1555694362.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot( y = 'tip', x = 'time', data= data, palette=colors)

# %%
time = ['Lunch','Dinner']
for i in time:
    subset = data[data['time'] == i]
    sns.distplot(subset['total_bill'], kde=True, kde_kws = {'fill':True}, hist=False, label=i)

plt.show()
# Out:
# C:\Users\prane\AppData\Local\Temp\ipykernel_16580\2407511123.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(subset['total_bill'], kde=True, kde_kws = {'fill':True}, hist=False, label=i)
# C:\Users\prane\AppData\Local\Temp\ipykernel_16580\2407511123.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.pairplot(data)
plt.show()

# %%
sns.countplot(data = data, x='day',hue='time')
plt.show()

# %%
corr_matrix = data[['tip','total_bill','size']].corr()
corr_matrix
# Out:
#                  tip  total_bill      size
# tip         1.000000    0.675734  0.489299
# total_bill  0.675734    1.000000  0.598315
# size        0.489299    0.598315  1.000000

# %%
sns.heatmap(corr_matrix,annot=True)
plt.show()
